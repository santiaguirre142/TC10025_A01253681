# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
edu = pd.read_csv('Pace_of_life.csv', na_values = ':',
                   usecols = ["City","Walk","Bank", "Talk", "Heart"])
edu
# Out:
#               City  Walk  Bank  Talk  Heart
# 0           Boston    28    31    24     24
# 1          Buffalo    23    30    23     29
# 2         New York    24    29    18     31
# 3   Salt Lake City    28    28    23     26
# 4         Columbus    22    27    30     26
# 5        Worcester    25    26    24     20
# 6       Providence    26    30    24     17
# 7      Springfield    30    28    21     19
# 8        Rochester    22    33    18     26
# 9      Kansas City    22    33    22     24
# 10        St Louis    23    22    23     26
# 11         Houston    25    30    20     25
# 12        Paterson    23    32    23     14
# 13     Bakersfield    18    29    25     11
# 14         Atlanta    27    25    27     19
# 15         Detroit    22    24    14     24
# 16      Youngstown    23    27    24     20
# 17    Indianapolis    22    26    24     13
# 18         Chicago    23    24    25     20
# 19    Philadelphia    12    31    19     18
# ...

# %%
edu.head()
# Out:
#              City  Walk  Bank  Talk  Heart
# 0          Boston    28    31    24     24
# 1         Buffalo    23    30    23     29
# 2        New York    24    29    18     31
# 3  Salt Lake City    28    28    23     26
# 4        Columbus    22    27    30     26

# %%
edu.tail()
# Out:
#            City  Walk  Bank  Talk  Heart
# 31      Memphis    16    29    21     14
# 32     San Jose    17    25    18     19
# 33   Shreveport    17    22    15     15
# 34   Sacramento    16    24    10     18
# 35  Los Angeles    20    13    12     16

# %%
edu.describe()
# Out:
#             Walk       Bank       Talk      Heart
# count  36.000000  36.000000  36.000000  36.000000
# mean   21.416667  26.361111  20.750000  19.805556
# std     4.285357   4.408776   4.129165   5.214373
# min    12.000000  13.000000  10.000000  11.000000
# 25%    18.750000  24.000000  18.000000  16.000000
# 50%    22.000000  26.500000  22.000000  19.000000
# 75%    23.250000  29.250000  23.250000  24.000000
# max    30.000000  34.000000  30.000000  31.000000

# %%
edu.columns
# Out:
# Index(['City', 'Walk', 'Bank', 'Talk', 'Heart'], dtype='object')

# %%
edu.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
edu.values
# Out:
# array([['Boston', 28, 31, 24, 24],
#        ['Buffalo', 23, 30, 23, 29],
#        ['New York', 24, 29, 18, 31],
#        ['Salt Lake City', 28, 28, 23, 26],
#        ['Columbus', 22, 27, 30, 26],
#        ['Worcester', 25, 26, 24, 20],
#        ['Providence', 26, 30, 24, 17],
#        ['Springfield', 30, 28, 21, 19],
#        ['Rochester', 22, 33, 18, 26],
#        ['Kansas City', 22, 33, 22, 24],
#        ['St Louis', 23, 22, 23, 26],
#        ['Houston', 25, 30, 20, 25],
#        ['Paterson', 23, 32, 23, 14],
#        ['Bakersfield', 18, 29, 25, 11],
#        ['Atlanta', 27, 25, 27, 19],
#        ['Detroit', 22, 24, 14, 24],
#        ['Youngstown', 23, 27, 24, 20],
#        ['Indianapolis', 22, 26, 24, 13],
#        ['Chicago', 23, 24, 25, 20],
#        ['Philadelphia', 12, 31, 19, 18],
#        ['Loiusville', 23, 27, 17, 16],
#        ['Canton', 20, 28, 18, 19],
#        ['Knoxville', 20, 21, 17, 23],
#        ['San Francisco', 22, 19, 18, 11],
# ...

# %%
edu['Heart']
# Out:
# 0     24
# 1     29
# 2     31
# 3     26
# 4     26
# 5     20
# 6     17
# 7     19
# 8     26
# 9     24
# 10    26
# 11    25
# 12    14
# 13    11
# 14    19
# 15    24
# 16    20
# 17    13
# 18    20
# 19    18
# 20    16
# 21    19
# 22    23
# 23    11
# 24    27
# 25    18
# 26    15
# 27    20
# 28    18
# 29    21
# 30    11
# 31    14
# 32    19
# 33    15
# 34    18
# 35    16
# Name: Heart, dtype: int64

# %%
edu[['City', 'Heart']]
# Out:
#               City  Heart
# 0           Boston     24
# 1          Buffalo     29
# 2         New York     31
# 3   Salt Lake City     26
# 4         Columbus     26
# 5        Worcester     20
# 6       Providence     17
# 7      Springfield     19
# 8        Rochester     26
# 9      Kansas City     24
# 10        St Louis     26
# 11         Houston     25
# 12        Paterson     14
# 13     Bakersfield     11
# 14         Atlanta     19
# 15         Detroit     24
# 16      Youngstown     20
# 17    Indianapolis     13
# 18         Chicago     20
# 19    Philadelphia     18
# 20      Loiusville     16
# 21          Canton     19
# 22       Knoxville     23
# 23   San Francisco     11
# 24     Chattanooga     27
# 25          Dallas     18
# 26          Oxnard     15
# 27       Nashville     20
# 28       San Diego     18
# 29    East Lansing     21
# 30          Fresno     11
# 31         Memphis     14
# 32        San Jose     19
# 33      Shreveport     15
# ...

# %%
edu[10:14]
# Out:
#            City  Walk  Bank  Talk  Heart
# 10     St Louis    23    22    23     26
# 11      Houston    25    30    20     25
# 12     Paterson    23    32    23     14
# 13  Bakersfield    18    29    25     11

# %%
edu.iloc[90:94, [0,1]]
# Out:
# Empty DataFrame
# Columns: [City, Walk]
# Index: []

# %%
edu.loc[90:94, ["City","Heart"]]
# Out:
# Empty DataFrame
# Columns: [City, Heart]
# Index: []

# %%
edu[edu['Heart'] > 20]. tail ()
# Out:
#             City  Walk  Bank  Talk  Heart
# 11       Houston    25    30    20     25
# 15       Detroit    22    24    14     24
# 22     Knoxville    20    21    17     23
# 24   Chattanooga    14    34    22     27
# 29  East Lansing    23    22    23     21

# %%
edu[edu["Heart"].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [City, Walk, Bank, Talk, Heart]
# Index: []

# %%
edu.max(axis = 0)
# Out:
# City     Youngstown
# Walk             30
# Bank             34
# Talk             30
# Heart            31
# dtype: object

# %%
print ("Función max en Pandas:", edu['Heart'].max())
print ("Función max en Python:", max(edu['Heart']))
# Out:
# Función max en Pandas: 31
# Función max en Python: 31

# %%
s = edu["Heart"]/100
s.head ()
# Out:
# 0    0.24
# 1    0.29
# 2    0.31
# 3    0.26
# 4    0.26
# Name: Heart, dtype: float64

# %%
s = edu["Heart"].apply(np.sqrt)
s.head ()
# Out:
# 0    4.898979
# 1    5.385165
# 2    5.567764
# 3    5.099020
# 4    5.099020
# Name: Heart, dtype: float64

# %%
s = edu["Heart"].apply(lambda d: d**2)
s.head ()
# Out:
# 0    576
# 1    841
# 2    961
# 3    676
# 4    676
# Name: Heart, dtype: int64

# %%
edu['HeartNorm'] = edu['Heart']/edu['Heart'].max()
edu.tail()
# Out:
#            City  Walk  Bank  Talk  Heart  HeartNorm
# 31      Memphis    16    29    21     14   0.451613
# 32     San Jose    17    25    18     19   0.612903
# 33   Shreveport    17    22    15     15   0.483871
# 34   Sacramento    16    24    10     18   0.580645
# 35  Los Angeles    20    13    12     16   0.516129

# %%
edu.drop('HeartNorm', axis = 1, inplace = True)
edu.head()
# Out:
#              City  Walk  Bank  Talk  Heart
# 0          Boston    28    31    24     24
# 1         Buffalo    23    30    23     29
# 2        New York    24    29    18     31
# 3  Salt Lake City    28    28    23     26
# 4        Columbus    22    27    30     26

# %%
edu = edu.append ({"Talk": 2000,"City": 5.00,"Heart": 'a'}, ignore_index = True)
edu.tail()
# Out:
#            City  Walk  Bank  Talk Heart
# 32     San Jose  17.0  25.0    18    19
# 33   Shreveport  17.0  22.0    15    15
# 34   Sacramento  16.0  24.0    10    18
# 35  Los Angeles  20.0  13.0    12    16
# 36            5   NaN   NaN  2000     a

# %%
edu.drop(max(edu.index), axis = 0, inplace = True)
edu.tail()
# Out:
#            City  Walk  Bank  Talk Heart
# 31      Memphis  16.0  29.0    21    14
# 32     San Jose  17.0  25.0    18    19
# 33   Shreveport  17.0  22.0    15    15
# 34   Sacramento  16.0  24.0    10    18
# 35  Los Angeles  20.0  13.0    12    16

# %%
eduDrop = edu.dropna(how = 'any', subset = ["City"])
eduDrop.head()
# Out:
#              City  Walk  Bank  Talk Heart
# 0          Boston  28.0  31.0    24    24
# 1         Buffalo  23.0  30.0    23    29
# 2        New York  24.0  29.0    18    31
# 3  Salt Lake City  28.0  28.0    23    26
# 4        Columbus  22.0  27.0    30    26

# %%
edu[edu.Heart.notnull()].tail()
# Out:
#            City  Walk  Bank  Talk Heart
# 31      Memphis  16.0  29.0    21    14
# 32     San Jose  17.0  25.0    18    19
# 33   Shreveport  17.0  22.0    15    15
# 34   Sacramento  16.0  24.0    10    18
# 35  Los Angeles  20.0  13.0    12    16

# %%
eduFilled = edu.fillna(value = {"Heart": 0})
eduFilled.head()
# Out:
#              City  Walk  Bank  Talk  Heart
# 0          Boston  28.0  31.0    24     24
# 1         Buffalo  23.0  30.0    23     29
# 2        New York  24.0  29.0    18     31
# 3  Salt Lake City  28.0  28.0    23     26
# 4        Columbus  22.0  27.0    30     26

# %%
edu.sort_values(by = 'Heart', ascending = False , inplace = True)
edu.head()
# Out:
#               City  Walk  Bank  Talk Heart
# 2         New York  24.0  29.0    18    31
# 1          Buffalo  23.0  30.0    23    29
# 24     Chattanooga  14.0  34.0    22    27
# 3   Salt Lake City  28.0  28.0    23    26
# 4         Columbus  22.0  27.0    30    26

# %%
edu.sort_index(axis = 0, ascending = True , inplace = True)
edu.head()
# Out:
#              City  Walk  Bank  Talk Heart
# 0          Boston  28.0  31.0    24    24
# 1         Buffalo  23.0  30.0    23    29
# 2        New York  24.0  29.0    18    31
# 3  Salt Lake City  28.0  28.0    23    26
# 4        Columbus  22.0  27.0    30    26

# %%
group = edu[["Heart", "City"]].groupby('Heart')
group

# %%
group = edu[["Heart", "City"]].groupby('Heart')
group.head()
# Out:
#    Heart            City
# 0     24          Boston
# 1     29         Buffalo
# 2     31        New York
# 3     26  Salt Lake City
# 4     26        Columbus
# 5     20       Worcester
# 6     17      Providence
# 7     19     Springfield
# 8     26       Rochester
# 9     24     Kansas City
# 10    26        St Louis
# 11    25         Houston
# 12    14        Paterson
# 13    11     Bakersfield
# 14    19         Atlanta
# 15    24         Detroit
# 16    20      Youngstown
# 17    13    Indianapolis
# 18    20         Chicago
# 19    18    Philadelphia
# 20    16      Loiusville
# 21    19          Canton
# 22    23       Knoxville
# 23    11   San Francisco
# 24    27     Chattanooga
# 25    18          Dallas
# 26    15          Oxnard
# 27    20       Nashville
# 28    18       San Diego
# 29    21    East Lansing
# 30    11          Fresno
# 31    14         Memphis
# 32    19        San Jose
# 33    15      Shreveport
# 34    18      Sacramento
# 35    16     Los Angeles

# %%
filtered_data = edu[edu['Heart'] > 20]
pivedu = pd.pivot_table(filtered_data , values = 'Talk',
                        index = ['City'],
                        columns = ['Heart'])
pivedu.head()
# Out:
# Heart        21  23    24  25    26    27    29  31
# City
# Boston      NaN NaN  24.0 NaN   NaN   NaN   NaN NaN
# Buffalo     NaN NaN   NaN NaN   NaN   NaN  23.0 NaN
# Chattanooga NaN NaN   NaN NaN   NaN  22.0   NaN NaN
# Columbus    NaN NaN   NaN NaN  30.0   NaN   NaN NaN
# Detroit     NaN NaN  14.0 NaN   NaN   NaN   NaN NaN

# %%
pivedu
# Out:
# Heart             21    23    24    25    26    27    29    31
# City
# Boston           NaN   NaN  24.0   NaN   NaN   NaN   NaN   NaN
# Buffalo          NaN   NaN   NaN   NaN   NaN   NaN  23.0   NaN
# Chattanooga      NaN   NaN   NaN   NaN   NaN  22.0   NaN   NaN
# Columbus         NaN   NaN   NaN   NaN  30.0   NaN   NaN   NaN
# Detroit          NaN   NaN  14.0   NaN   NaN   NaN   NaN   NaN
# East Lansing    23.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Houston          NaN   NaN   NaN  20.0   NaN   NaN   NaN   NaN
# Kansas City      NaN   NaN  22.0   NaN   NaN   NaN   NaN   NaN
# Knoxville        NaN  17.0   NaN   NaN   NaN   NaN   NaN   NaN
# New York         NaN   NaN   NaN   NaN   NaN   NaN   NaN  18.0
# Rochester        NaN   NaN   NaN   NaN  18.0   NaN   NaN   NaN
# Salt Lake City   NaN   NaN   NaN   NaN  23.0   NaN   NaN   NaN
# St Louis         NaN   NaN   NaN   NaN  23.0   NaN   NaN   NaN

# %%
pivedu.rank(ascending = False , method = 'first').head()
# Out:
# Heart        21  23   24  25   26   27   29  31
# City
# Boston      NaN NaN  1.0 NaN  NaN  NaN  NaN NaN
# Buffalo     NaN NaN  NaN NaN  NaN  NaN  1.0 NaN
# Chattanooga NaN NaN  NaN NaN  NaN  1.0  NaN NaN
# Columbus    NaN NaN  NaN NaN  1.0  NaN  NaN NaN
# Detroit     NaN NaN  3.0 NaN  NaN  NaN  NaN NaN

# %%
totalSum = pivedu.sum(axis = 1)
totalSum.rank(ascending = False , method = 'dense').sort_values().head()
# Out:
# City
# Columbus          1.0
# Boston            2.0
# Buffalo           3.0
# East Lansing      3.0
# Salt Lake City    3.0
# dtype: float64

# %%
totalSum = pivedu.sum(axis = 1).sort_values(ascending = False)
totalSum.plot(kind = 'bar', style = 'b', alpha = 0.4,
              title = "Total Values for Country")
# Out:
# <AxesSubplot:title={'center':'Total Values for Country'}, xlabel='City'>

# %%
my_colors = ['blue', 'red', 'green', 'yellow', 'magenta', 'cyan']
ax = pivedu.plot(kind = 'barh', stacked = True, color = my_colors)
ax.legend(loc = 'center left', bbox_to_anchor = (1, .5))
